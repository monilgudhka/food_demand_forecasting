# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("../data/train/train_feature.csv", index_col='id')
dataset.head()
# Out:
#          num_orders  week  center_id  meal_id  checkout_price  base_price  \
# id
# 1379560         177     1         55     1885          136.83      152.29
# 1466964         270     1         55     1993          136.83      135.83
# 1346989         189     1         55     2539          134.86      135.86
# 1338232          54     1         55     2139          339.50      437.53
# 1448490          40     1         55     2631          243.50      242.50
#
#          emailer_for_promotion  homepage_featured  city_code  region_code  \
# id
# 1379560                      0                  0        647           56
# 1466964                      0                  0        647           56
# 1346989                      0                  0        647           56
# 1338232                      0                  0        647           56
# 1448490                      0                  0        647           56
#
#          ... average_orders_13week_across  average_orders_26week_across  \
# id       ...
# 1379560  ...                   726.506494                    726.506494
# 1466964  ...                   793.896104                    793.896104
# 1346989  ...                   272.116883                    272.116883
# 1338232  ...                    49.709677                     49.709677
# 1448490  ...                    74.014085                     74.014085
#
#         average_orders_52week_across average_orders_13week_adj_across  \
# id
# 1379560                   726.506494                              NaN
# 1466964                   793.896104                              NaN
# 1346989                   272.116883                              NaN
# 1338232                    49.709677                              NaN
# 1448490                    74.014085                              NaN
#
#          average_orders_26week_adj_across  discount  year  month  quarter  \
# id
# 1379560                               NaN  0.101517     1      1        1
# 1466964                               NaN -0.007362     1      1        1
# 1346989                               NaN  0.007361     1      1        1
# 1338232                               NaN  0.224053     1      1        1
# 1448490                               NaN -0.004124     1      1        1
#
#          week_in_month
# id
# 1379560              1
# 1466964              1
# 1346989              1
# 1338232              1
# 1448490              1
#
# [5 rows x 30 columns]

# %%
categorical_columns = ['week', 'center_id', 'meal_id', 'emailer_for_promotion', 'homepage_featured', 'city_code', 
                       'region_code', 'center_type', 'category', 'cuisine','year','month','week_in_month', 'quarter']
for column in categorical_columns:
    dataset[column] = dataset[column].astype('category')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456548 entries, 1379560 to 1361984
# Data columns (total 30 columns):
# num_orders                          456548 non-null int64
# week                                456548 non-null category
# center_id                           456548 non-null category
# meal_id                             456548 non-null category
# checkout_price                      456548 non-null float64
# base_price                          456548 non-null float64
# emailer_for_promotion               456548 non-null category
# homepage_featured                   456548 non-null category
# city_code                           456548 non-null category
# region_code                         456548 non-null category
# center_type                         456548 non-null category
# op_area                             456548 non-null float64
# category                            456548 non-null category
# cuisine                             456548 non-null category
# mean_base_price                     456548 non-null float64
# average_orders_13week               456548 non-null float64
# average_orders_26week               456548 non-null float64
# average_orders_52week               456548 non-null float64
# average_orders_13week_adj           422449 non-null float64
# average_orders_26week_adj           423016 non-null float64
# average_orders_13week_across        456548 non-null float64
# average_orders_26week_across        456548 non-null float64
# average_orders_52week_across        456548 non-null float64
# average_orders_13week_adj_across    426786 non-null float64
# average_orders_26week_adj_across    426786 non-null float64
# discount                            456548 non-null float64
# year                                456548 non-null category
# month                               456548 non-null category
# quarter                             456548 non-null category
# week_in_month                       456548 non-null category
# dtypes: category(14), float64(15), int64(1)
# memory usage: 65.8 MB

# %% [markdown]
# # Correlation between variables

# %%
correlation = dataset.corr()
correlation
# Out:
#                                   num_orders  checkout_price  base_price  \
# num_orders                          1.000000       -0.282108   -0.222306
# checkout_price                     -0.282108        1.000000    0.953389
# base_price                         -0.222306        0.953389    1.000000
# op_area                             0.176976        0.021569    0.018031
# mean_base_price                    -0.232571        0.948152    0.986845
# average_orders_13week               0.756832       -0.288132   -0.288508
# average_orders_26week               0.737665       -0.291632   -0.295824
# average_orders_52week               0.732134       -0.297826   -0.303439
# average_orders_13week_adj           0.673540       -0.273262   -0.286354
# average_orders_26week_adj           0.683755       -0.281528   -0.293892
# average_orders_13week_across        0.566346       -0.394371   -0.393701
# average_orders_26week_across        0.551851       -0.398821   -0.402686
# average_orders_52week_across        0.549713       -0.404876   -0.410488
# average_orders_13week_adj_across    0.494366       -0.376117   -0.390527
# average_orders_26week_adj_across    0.503139       -0.385883   -0.399376
# discount                            0.161900       -0.281215   -0.056287
#
#                                    op_area  mean_base_price  \
# num_orders                        0.176976        -0.232571
# checkout_price                    0.021569         0.948152
# base_price                        0.018031         0.986845
# op_area                           1.000000         0.020256
# mean_base_price                   0.020256         1.000000
# average_orders_13week             0.227814        -0.303881
# average_orders_26week             0.231416        -0.312461
# average_orders_52week             0.232058        -0.320488
# average_orders_13week_adj         0.225468        -0.304761
# average_orders_26week_adj         0.228815        -0.312837
# average_orders_13week_across     -0.057606        -0.413209
# average_orders_26week_across     -0.058530        -0.423458
# average_orders_52week_across     -0.058776        -0.431617
# average_orders_13week_adj_across -0.057015        -0.413077
# average_orders_26week_adj_across -0.057852        -0.422445
# discount                          0.000572         0.007261
#
#                                   average_orders_13week  \
# num_orders                                     0.756832
# checkout_price                                -0.288132
# base_price                                    -0.288508
# op_area                                        0.227814
# mean_base_price                               -0.303881
# average_orders_13week                          1.000000
# average_orders_26week                          0.975211
# average_orders_52week                          0.959128
# average_orders_13week_adj                      0.909107
# average_orders_26week_adj                      0.906696
# average_orders_13week_across                   0.750934
# average_orders_26week_across                   0.731412
# average_orders_52week_across                   0.721023
# average_orders_13week_adj_across               0.672629
# average_orders_26week_adj_across               0.672369
# discount                                      -0.042415
#
#                                   average_orders_26week  \
# num_orders                                     0.737665
# checkout_price                                -0.291632
# base_price                                    -0.295824
# op_area                                        0.231416
# mean_base_price                               -0.312461
# average_orders_13week                          0.975211
# average_orders_26week                          1.000000
# average_orders_52week                          0.985258
# average_orders_13week_adj                      0.963397
# average_orders_26week_adj                      0.961057
# average_orders_13week_across                   0.733994
# average_orders_26week_across                   0.753687
# average_orders_52week_across                   0.743097
# average_orders_13week_adj_across               0.717358
# average_orders_26week_adj_across               0.716627
# discount                                      -0.061453
#
#                                   average_orders_52week  \
# num_orders                                     0.732134
# checkout_price                                -0.297826
# base_price                                    -0.303439
# op_area                                        0.232058
# mean_base_price                               -0.320488
# average_orders_13week                          0.959128
# average_orders_26week                          0.985258
# average_orders_52week                          1.000000
# average_orders_13week_adj                      0.945956
# average_orders_26week_adj                      0.969241
# average_orders_13week_across                   0.727912
# average_orders_26week_across                   0.747439
# average_orders_52week_across                   0.758297
# average_orders_13week_adj_across               0.708915
# average_orders_26week_adj_across               0.727026
# discount                                      -0.067993
#
#                                   average_orders_13week_adj  \
# num_orders                                         0.673540
# checkout_price                                    -0.273262
# base_price                                        -0.286354
# op_area                                            0.225468
# mean_base_price                                   -0.304761
# average_orders_13week                              0.909107
# average_orders_26week                              0.963397
# average_orders_52week                              0.945956
# average_orders_13week_adj                          1.000000
# average_orders_26week_adj                          0.974758
# average_orders_13week_across                       0.678954
# average_orders_26week_across                       0.721597
# average_orders_52week_across                       0.708403
# average_orders_13week_adj_across                   0.752246
# average_orders_26week_adj_across                   0.732249
# discount                                          -0.099552
#
#                                   average_orders_26week_adj  \
# num_orders                                         0.683755
# checkout_price                                    -0.281528
# base_price                                        -0.293892
# op_area                                            0.228815
# mean_base_price                                   -0.312837
# average_orders_13week                              0.906696
# average_orders_26week                              0.961057
# average_orders_52week                              0.969241
# average_orders_13week_adj                          0.974758
# average_orders_26week_adj                          1.000000
# average_orders_13week_across                       0.681306
# average_orders_26week_across                       0.723485
# average_orders_52week_across                       0.729340
# average_orders_13week_adj_across                   0.734878
# average_orders_26week_adj_across                   0.755120
# discount                                          -0.100582
#
#                                   average_orders_13week_across  \
# num_orders                                            0.566346
# checkout_price                                       -0.394371
# base_price                                           -0.393701
# op_area                                              -0.057606
# mean_base_price                                      -0.413209
# average_orders_13week                                 0.750934
# average_orders_26week                                 0.733994
# average_orders_52week                                 0.727912
# average_orders_13week_adj                             0.678954
# average_orders_26week_adj                             0.681306
# average_orders_13week_across                          1.000000
# average_orders_26week_across                          0.973883
# average_orders_52week_across                          0.959939
# average_orders_13week_adj_across                      0.901243
# average_orders_26week_adj_across                      0.900758
# discount                                             -0.043122
#
#                                   average_orders_26week_across  \
# num_orders                                            0.551851
# checkout_price                                       -0.398821
# base_price                                           -0.402686
# op_area                                              -0.058530
# mean_base_price                                      -0.423458
# average_orders_13week                                 0.731412
# average_orders_26week                                 0.753687
# average_orders_52week                                 0.747439
# average_orders_13week_adj                             0.721597
# average_orders_26week_adj                             0.723485
# average_orders_13week_across                          0.973883
# average_orders_26week_across                          1.000000
# average_orders_52week_across                          0.985744
# average_orders_13week_adj_across                      0.957597
# average_orders_26week_adj_across                      0.956408
# discount                                             -0.064799
#
#                                   average_orders_52week_across  \
# num_orders                                            0.549713
# checkout_price                                       -0.404876
# base_price                                           -0.410488
# op_area                                              -0.058776
# mean_base_price                                      -0.431617
# average_orders_13week                                 0.721023
# average_orders_26week                                 0.743097
# average_orders_52week                                 0.758297
# average_orders_13week_adj                             0.708403
# average_orders_26week_adj                             0.729340
# average_orders_13week_across                          0.959939
# average_orders_26week_across                          0.985744
# average_orders_52week_across                          1.000000
# average_orders_13week_adj_across                      0.939989
# average_orders_26week_adj_across                      0.963964
# discount                                             -0.071809
#
#                                   average_orders_13week_adj_across  \
# num_orders                                                0.494366
# checkout_price                                           -0.376117
# base_price                                               -0.390527
# op_area                                                  -0.057015
# mean_base_price                                          -0.413077
# average_orders_13week                                     0.672629
# average_orders_26week                                     0.717358
# average_orders_52week                                     0.708915
# average_orders_13week_adj                                 0.752246
# average_orders_26week_adj                                 0.734878
# average_orders_13week_across                              0.901243
# average_orders_26week_across                              0.957597
# average_orders_52week_across                              0.939989
# average_orders_13week_adj_across                          1.000000
# average_orders_26week_adj_across                          0.973401
# discount                                                 -0.109537
#
#                                   average_orders_26week_adj_across  discount
# num_orders                                                0.503139  0.161900
# checkout_price                                           -0.385883 -0.281215
# base_price                                               -0.399376 -0.056287
# op_area                                                  -0.057852  0.000572
# mean_base_price                                          -0.422445  0.007261
# average_orders_13week                                     0.672369 -0.042415
# average_orders_26week                                     0.716627 -0.061453
# average_orders_52week                                     0.727026 -0.067993
# average_orders_13week_adj                                 0.732249 -0.099552
# average_orders_26week_adj                                 0.755120 -0.100582
# average_orders_13week_across                              0.900758 -0.043122
# average_orders_26week_across                              0.956408 -0.064799
# average_orders_52week_across                              0.963964 -0.071809
# average_orders_13week_adj_across                          0.973401 -0.109537
# average_orders_26week_adj_across                          1.000000 -0.109749
# discount                                                 -0.109749  1.000000

# %%
_ = sns.heatmap(correlation)
_ = plt.title("Correlation between continuous variables")
plt.savefig('figure/correlation_between_continous_variables.jpg', bbox_inches="tight")
plt.show()

# %% [markdown]
# <p>The checkout price and base price has high positive correlation with each other and negative correlation with number of orders. It make sense, customer will order cheaper meals more than costly meals.</p>
# <p>The operating area and discount has low positive correlation with other variables.</p>

# %% [markdown]
# # Promotion Activity

# %%
# Function to draw samples, it will be used in performing tests
def draw_samples(series, statistic=np.mean, replicas=10000):
    size = series.shape[0]
    sample_data = [statistic(series.sample(n=size, replace=True)) for _ in range(replicas)]
    return np.array(sample_data)

# %%
promotion = dataset['emailer_for_promotion'].astype('int') + dataset['homepage_featured'].astype('int')
promotion.value_counts()
# Out:
# 0    388874
# 1     48443
# 2     19231
# dtype: int64

# %% [markdown]
# In the dataset, there are two types of promotional activity, viz. promotion by emails and promotion in homepage of website. Sometimes both activities were performed but most of the time any one was performed. Due to this, below questions are raised:
# 1. Does promotion by email results in increase in number of orders ?
# 2. Does promotion in homepage results in increase in number of orders ?
# 3. Since, there are activity in any one way, which promotional activity has higher impact on number of orders?

# %% [markdown]
# ### Does promotion by email results in increase in number of orders ?

# %% [markdown]
# <p>Let's perform hypothesis test to answer this question.</p>
# <p><b>Null Hypothesis: </b><i>The difference between the mean of number of orders with email promotion and without email promotion is less than or equal to zero.</i></p>
# <p><b>Alternate Hypothesis: </b><i>The difference between the mean of number of orders with email promotion and without email promotion is greater than zero.</i></p>

# %%
emailer_orders = dataset[dataset.emailer_for_promotion == 1]['num_orders']
non_emailer_orders = dataset[dataset.emailer_for_promotion == 0]['num_orders']

observed_mean_diff = emailer_orders.mean() - non_emailer_orders.mean()
mean_diff_bootstrap = draw_samples(emailer_orders) - draw_samples(non_emailer_orders)

confidence_interval = np.percentile(mean_diff_bootstrap, [5.0])
p_value = np.sum(mean_diff_bootstrap <= 0)/ len(mean_diff_bootstrap)

print("Observed mean difference: {}".format(observed_mean_diff))
print("Confidence Intervals: {}".format(confidence_interval))
print("P-value: {}".format(p_value))

# Plotting histogram
_ = plt.hist(mean_diff_bootstrap, bins=20, alpha=0.5)
_ = plt.xlabel("Difference between the mean")
_ = plt.ylabel("number of samples")
_ = plt.title("Email Promotion vs Non-email Promotion")

# Marking the 5% confidence interval
_ = plt.axvline(confidence_interval[0], color='k', linestyle='dashed', linewidth=1)
_ = plt.axvline(observed_mean_diff, color='g', linewidth=1)

plt.savefig('figure/diff_orders_email_promotion.jpg')
plt.show()
# Out:
# Observed mean difference: 401.83466060394824
# Confidence Intervals: [394.24961591]
# P-value: 0.0

# %% [markdown]
# <p>The P-value of above hypothesis test is statistically significant for given left-side 0.05 alpha. Hence, we reject the null hypothesis and accept the alternative hypothesis.</p>
# <p>The above Histogram also supports alternate hypothesis.</p>
# <p><b><i>Conclusion:</i> Promotion Activity by emails does increase the number of orders</b></p>

# %% [markdown]
# ### Does promotion in homepage results in increase in number of orders ?

# %% [markdown]
# <p>Let's perform hypothesis test to answer this question.</p>
# <p><b>Null Hypothesis: </b><i>The difference between the mean of number of orders with homepage promotion and without homepage promotion is less than or equal to zero.</i></p>
# <p><b>Alternate Hypothesis: </b><i>The difference between the mean of number of orders with homepage promotion and without homepage promotion is greater than zero.</i></p>

# %%
homepage_orders = dataset[dataset.homepage_featured == 1]['num_orders']
non_homepage_orders = dataset[dataset.homepage_featured == 0]['num_orders']

observed_mean_diff = homepage_orders.mean() - non_homepage_orders.mean()
mean_diff_bootstrap = draw_samples(homepage_orders) - draw_samples(non_homepage_orders)

confidence_interval = np.percentile(mean_diff_bootstrap, [5.0])
p_value = np.sum(mean_diff_bootstrap <= 0)/ len(mean_diff_bootstrap)

print("Observed mean difference: {}".format(observed_mean_diff))
print("Confidence Intervals: {}".format(confidence_interval))
print("P-value: {}".format(p_value))

# Plotting histogram
_ = plt.hist(mean_diff_bootstrap, bins=20, alpha=0.5)
_ = plt.xlabel("Difference between the mean")
_ = plt.ylabel("number of samples")
_ = plt.title("Homepage Promotion vs Non-homepage Promotion")

# Marking the 5% confidence interval
_ = plt.axvline(confidence_interval[0], color='k', linestyle='dashed', linewidth=1)
_ = plt.axvline(observed_mean_diff, color='g', linewidth=1)

plt.savefig('figure/diff_orders_homepage_promotion.jpg')
plt.show()
# Out:
# Observed mean difference: 373.8347456767344
# Confidence Intervals: [367.98293888]
# P-value: 0.0

# %% [markdown]
# <p>The P-value of above hypothesis test is statistically significant for given left-side 0.05 alpha. Hence, we reject the null hypothesis and accept the alternative hypothesis.</p>
# <p>The above Histogram also supports alternate hypothesis.</p>
# <p><b><i>Conclusion:</i> Promotion Activity in homepage does increase the number of orders</b></p>

# %% [markdown]
# ### Which promotional activity has higher impact on number of orders?

# %% [markdown]
# <p>Let's perform hypothesis test, on dataset were either promotion activity is perfromed, to answer this question.</p>
# <p><b>Null Hypothesis: </b><i>The difference between the mean of number of orders with homepage promotion and without homepage promotion is less than or equal to zero.</i></p>
# <p><b>Alternate Hypothesis: </b><i>The difference between the mean of number of orders with homepage promotion and without homepage promotion is greater than zero.</i></p>

# %%
either_activity = dataset[promotion == 1]

homepage_orders = either_activity[either_activity.homepage_featured == 1]['num_orders']
non_homepage_orders = either_activity[either_activity.homepage_featured == 0]['num_orders']

observed_mean_diff = homepage_orders.mean() - non_homepage_orders.mean()
mean_diff_bootstrap = draw_samples(homepage_orders) - draw_samples(non_homepage_orders)

confidence_interval = np.percentile(mean_diff_bootstrap, [5.0])
p_value = np.sum(mean_diff_bootstrap <= 0)/ len(mean_diff_bootstrap)

print("Observed mean difference: {}".format(observed_mean_diff))
print("Confidence Intervals: {}".format(confidence_interval))
print("P-value: {}".format(p_value))

# Plotting histogram
_ = plt.hist(mean_diff_bootstrap, bins=20, alpha=0.5)
_ = plt.xlabel("Difference between the mean")
_ = plt.ylabel("number of samples")
_ = plt.title("Email Promotion vs Homepage Promotion")

# Marking the 5% confidence interval
_ = plt.axvline(confidence_interval[0], color='k', linestyle='dashed', linewidth=1)
_ = plt.axvline(observed_mean_diff, color='g', linewidth=1)

plt.savefig('figure/impact_homepage_vs_email.jpg')
plt.show()
# Out:
# Observed mean difference: 24.59858319570185
# Confidence Intervals: [14.67342244]
# P-value: 0.0

# %% [markdown]
# <p>The P-value of above hypothesis test is statistically significant for given left-side 0.05 alpha. Hence, we reject the null hypothesis and accept the alternative hypothesis.</p>
# <p>The above Histogram also supports alternate hypothesis.</p>
# <p><b><i>Conclusion:</i> Promotion Activity in homepage has more impact than emails on increase in number of orders</b></p>
# <p><i>Note: This is only in case were there is any one activity.</i>

# %% [markdown]
# # Summary
#
# 1. The checkout price and base price has high positive correlation with each other
# 2. They also have negative correlation with number of orders
# 3. The operating area and discount has low positive correlation with other variables
# 4. Promotion Activity by emails does increase the number of orders
# 5. Promotion Activity in homepage does increase the number of orders
# 6. But Promotion activity in homepage has more impact than emails on increase in number of orders
